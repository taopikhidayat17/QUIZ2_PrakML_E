# %%
import numpy as pd
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv("Datacovid19.csv")

# %%
data.head()
# Out:
#   Province/State  Country/Region      Last Update  Confirmed  Deaths  \
# 0          Hubei  Mainland China  1/22/2020 17:00        444    17.0
# 1          Hubei  Mainland China    1/23/20 17:00        444    17.0
# 2          Hubei  Mainland China    1/23/20 17:00        444    17.0
# 3          Hubei  Mainland China    1/24/20 17:00        549    24.0
# 4          Hubei  Mainland China    1/25/20 17:00        761    40.0
#
#    Recovered
# 0       28.0
# 1       28.0
# 2       28.0
# 3       31.0
# 4       32.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101795 entries, 0 to 101794
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Province/State  101795 non-null  object
#  1   Country/Region  101795 non-null  object
#  2   Last Update     101795 non-null  object
#  3   Confirmed       101795 non-null  int64
#  4   Deaths          101794 non-null  float64
#  5   Recovered       101794 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.7+ MB

# %%
data['Last Update'].unique()
# Out:
# array(['1/22/2020 17:00', '1/23/20 17:00', '1/24/20 17:00', ...,
#        '26/01/2021 05.22', '27/01/2021 05.23', '28/01/2021 05.22'],
#       dtype=object)

# %%
latest_date = '28/02/2021 05.22'
data[data['Last Update']==latest_date]
# Out:
# Empty DataFrame
# Columns: [Province/State, Country/Region, Last Update, Confirmed, Deaths, Recovered]
# Index: []

# %%
unique_countries = data[data.Confirmed>0]['Country/Region'].unique()
unique_countries.sort()
unique_countries
# Out:
# array(['Australia', 'Brazil', 'Canada', 'Chile', 'Colombia', 'Denmark',
#        'France', 'Germany', 'Hong Kong', 'India', 'Italy', 'Japan',
#        'Mainland China', 'Mexico', 'Netherlands', 'Others', 'Pakistan',
#        'Peru', 'Russia', 'Spain', 'Taiwan', 'UK', 'US', 'Ukraine'],
#       dtype=object)

# %%
country_confirmed_case = []
for i in unique_countries:
    country_confirmed_case.append(data[data.Confirmed>0][data['Country/Region']==i][data['Last Update']==latest_date].Confirmed.sum())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(set(zip(unique_countries, country_confirmed_case)))
# Out:
# {('Ukraine', 0), ('Mainland China', 0), ('Germany', 0), ('Pakistan', 0), ('Hong Kong', 0), ('Chile', 0), ('UK', 0), ('Spain', 0), ('Taiwan', 0), ('Japan', 0), ('US', 0), ('Peru', 0), ('Denmark', 0), ('Russia', 0), ('Others', 0), ('Australia', 0), ('Mexico', 0), ('Canada', 0), ('Netherlands', 0), ('Brazil', 0), ('France', 0), ('Colombia', 0), ('India', 0), ('Italy', 0)}

# %%
unique_provinces = data['Province/State'][data.Confirmed>1].unique()
unique_provinces
# Out:
# array(['Hubei', 'Shanghai', 'Beijing', 'Henan', 'Sichuan', 'Hainan',
#        'Chongqing', 'Heilongjiang', 'Hebei', 'Tianjin', 'Guizhou',
#        'Guangdong', 'Jilin', 'Hunan', 'Gansu', 'Anhui', 'Shandong',
#        'Guangxi', 'Jiangxi', 'Liaoning', 'Hong Kong', 'Xinjiang',
#        'Taiwan', 'Yunnan', 'Zhejiang', 'Diamond Princess cruise ship',
#        'Fujian', 'Shaanxi', 'Seattle, WA', 'King County, WA',
#        'Inner Mongolia', 'New South Wales', 'British Columbia',
#        'Washington', 'California', 'France', 'UK', 'United Kingdom',
#        'Denmark', 'Netherlands', 'New Jersey', 'Kentucky', 'Ontario',
#        'Illinois', 'Western Australia', 'French Polynesia', 'Curacao',
#        'Queensland', 'Victoria', 'Guadeloupe',
#        'Australian Capital Territory', 'St Martin', 'Martinique',
#        'Mayotte', 'Tasmania', 'Sint Maarten', 'Channel Islands',
#        'Cayman Islands', 'Bermuda', 'Isle of Man', 'South Australia',
#        'Aruba', 'British Virgin Islands', 'French Guiana',
#        'Turks and Caicos Islands', 'Montserrat', 'Abruzzo', 'Alberta',
#        'Andalusia', 'Aragon', 'Asturias', 'Baden-Wurttemberg', 'Baleares',
#        'Basilicata', 'Bayern', 'Berlin', 'Brandenburg', 'Bremen',
#        'C. Valenciana', 'Calabria', 'Campania', 'Canarias', 'Cantabria',
#        'Castilla - La Mancha', 'Castilla y Leon', 'Catalonia', 'Ceuta',
#        'Emilia-Romagna', 'Extremadura', 'Friuli Venezia Giulia',
#        'Galicia', 'Hamburg', 'Hessen', 'La Rioja', 'Lazio', 'Liguria',
#        'Lombardia', 'Madrid', 'Manitoba', 'Marche',
#        'Mecklenburg-Vorpommern', 'Melilla', 'Molise', 'Murcia', 'Navarra',
#        'Newfoundland and Labrador', 'Niedersachsen',
#        'Nordrhein-Westfalen', 'Nova Scotia', 'P.A. Bolzano',
#        'P.A. Trento', 'Pais Vasco', 'Piemonte', 'Puglia', 'Quebec',
#        'Rheinland-Pfalz', 'Saarland', 'Sachsen', 'Sachsen-Anhalt',
#        'Sardegna', 'Saskatchewan', 'Schleswig-Holstein', 'Sicilia',
#        'Thuringen', 'Toscana', 'Umbria', 'Unknown', "Valle d'Aosta",
#        'Veneto', 'Aguascalientes', 'Baja California',
#        'Baja California Sur', 'Campeche', 'Chiapas', 'Chihuahua',
#        'Ciudad de Mexico', 'Coahuila', 'Colima', 'Durango', 'Guanajuato',
#        'Guerrero', 'Hidalgo', 'Jalisco', 'Mexico', 'Michoacan', 'Morelos',
#        'Nayarit', 'Nuevo Leon', 'Oaxaca', 'Puebla', 'Queretaro',
#        'Quintana Roo', 'Reunion', 'San Luis Potosi', 'Sinaloa', 'Sonora',
#        'Tabasco', 'Tamaulipas', 'Tlaxcala', 'Veracruz', 'Yucatan',
#        'Zacatecas', 'Aichi', 'Amazonas', 'Antioquia', 'Aomori',
#        'Atlantico', 'Bolivar', 'Boyaca', 'Caldas', 'Capital District',
#        'Caqueta', 'Cauca', 'Cesar', 'Chiba', 'Choco', 'Cordoba',
#        'Cundinamarca', 'Ehime', 'Fukui', 'Fukuoka', 'Gifu', 'Gunma',
#        'Hiroshima', 'Hokkaido', 'Huila', 'Hyogo', 'Ibaraki', 'Ishikawa',
#        'Kanagawa', 'Kochi', 'Kumamoto', 'Kyoto', 'La Guajira',
#        'Magdalena', 'Meta', 'Mie', 'Miyagi', 'Nagasaki', 'Nara', 'Narino',
#        'Norte de Santander', 'Oita', 'Okinawa', 'Osaka', 'Quindio',
#        'Risaralda', 'Saitama', 'Santander', 'Shiga', 'Shizuoka',
#        'Tokushima', 'Tokyo', 'Tolima', 'Toyama', 'Valle del Cauca',
#        'Wakayama', 'Yamanashi', 'Putumayo', 'Adygea Republic',
#        'Altai Krai', 'Amur Oblast', 'Arkhangelsk Oblast',
#        'Astrakhan Oblast', 'Bashkortostan Republic', 'Belgorod Oblast',
#        'Bryansk Oblast', 'Buryatia Republic', 'Chechen Republic',
#        'Chelyabinsk Oblast', 'Cherkasy Oblast', 'Chernihiv Oblast',
#        'Chernivtsi Oblast', 'Chukotka Autonomous Okrug',
#        'Chuvashia Republic', 'Crimea Republic*', 'Dagestan Republic',
#        'Dnipropetrovsk Oblast', 'Donetsk Oblast', 'Ingushetia Republic',
#        'Irkutsk Oblast', 'Ivano-Frankivsk Oblast', 'Ivanovo Oblast',
#        'Jewish Autonomous Okrug', 'Kabardino-Balkarian Republic',
#        'Kaliningrad Oblast', 'Kalmykia Republic', 'Kaluga Oblast',
#        'Kamchatka Krai', 'Karachay-Cherkess Republic', 'Karelia Republic',
#        'Kemerovo Oblast', 'Khabarovsk Krai', 'Khakassia Republic',
#        'Khanty-Mansi Autonomous Okrug', 'Kharkiv Oblast',
#        'Kherson Oblast', 'Khmelnytskyi Oblast', 'Kiev', 'Kiev Oblast',
#        'Kirov Oblast', 'Kirovohrad Oblast', 'Komi Republic',
#        'Kostroma Oblast', 'Krasnodar Krai', 'Krasnoyarsk Krai',
#        'Kursk Oblast', 'Leningrad Oblast', 'Lipetsk Oblast',
#        'Lviv Oblast', 'Magadan Oblast', 'Mari El Republic',
#        'Mordovia Republic', 'Moscow', 'Moscow Oblast', 'Murmansk Oblast',
#        'Mykolaiv Oblast', 'Nizhny Novgorod Oblast',
#        'North Ossetia - Alania Republic', 'Novgorod Oblast',
#        'Novosibirsk Oblast', 'Odessa Oblast', 'Omsk Oblast',
#        'Orel Oblast', 'Orenburg Oblast', 'Penza Oblast', 'Perm Krai',
#        'Poltava Oblast', 'Primorsky Krai', 'Pskov Oblast', 'Rivne Oblast',
#        'Rostov Oblast', 'Ryazan Oblast', 'Saint Petersburg',
#        'Sakha (Yakutiya) Republic', 'Samara Oblast', 'Saratov Oblast',
#        'Sevastopol*', 'Smolensk Oblast', 'Stavropol Krai', 'Sumy Oblast',
#        'Sverdlovsk Oblast', 'Tambov Oblast', 'Tatarstan Republic',
#        'Ternopil Oblast', 'Tomsk Oblast', 'Tula Oblast', 'Tver Oblast',
#        'Tyumen Oblast', 'Tyva Republic', 'Udmurt Republic',
#        'Ulyanovsk Oblast', 'Vinnytsia Oblast', 'Vladimir Oblast',
#        'Volgograd Oblast', 'Vologda Oblast', 'Volyn Oblast',
#        'Voronezh Oblast', 'Yamalo-Nenets Autonomous Okrug',
#        'Yaroslavl Oblast', 'Zabaykalsky Krai', 'Zakarpattia Oblast',
#        'Zaporizhia Oblast', 'Zhytomyr Oblast', 'New Brunswick',
#        'Casanare', 'Sucre', 'Acre', 'Alagoas', 'Amapa', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Maranhao', 'Mato Grosso',
#        'Mato Grosso do Sul', 'Minas Gerais', 'Para', 'Paraiba', 'Parana',
#        'Pernambuco', 'Piaui', 'Rio Grande do Norte', 'Rio Grande do Sul',
#        'Rio de Janeiro', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins', 'Michigan', 'Andhra Pradesh',
#        'Assam', 'Azad Jammu and Kashmir', 'Balochistan', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Delhi', 'Gilgit-Baltistan',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Islamabad',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Khyber Pakhtunkhwa', 'Ladakh', 'Madhya Pradesh', 'Maharashtra',
#        'Meghalaya', 'Odisha', 'Punjab', 'Rajasthan', 'Sindh',
#        'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'Puducherry', 'Guainia',
#        'San Andres y Providencia', 'Goa', 'Port Quarantine',
#        'Arunachal Pradesh', 'Kurgan Oblast', 'Antofagasta', 'Araucania',
#        'Arica y Parinacota', 'Atacama', 'Biobio', 'Coquimbo', 'Los Lagos',
#        'Los Rios', 'Magallanes', 'Maule', 'Metropolitana', 'Nuble',
#        'OHiggins', 'Tarapaca', 'Valparaiso', 'Altai Republic', 'Vaupes',
#        'Yamagata', 'Goias', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Luhansk Oblast', 'Aysen', 'Arauca', 'Nagaland',
#        'Andaman and Nicobar Islands', 'Sikkim', 'Kagoshima', 'Manipur',
#        'Tochigi', 'Miyazaki', 'Kagawa', 'Vichada', 'Guaviare', 'Okayama',
#        'Nagano', 'Yamaguchi', 'Bonaire, Sint Eustatius and Saba',
#        'Fukushima', 'Nenets Autonomous Okrug', 'Sakhalin Oblast', 'Saga',
#        'Mizoram', 'Yukon', 'Gibraltar', 'Iwate', 'Akita',
#        'Saint Barthelemy', 'Niigata', 'Nunavut', 'Faroe Islands',
#        'Tottori'], dtype=object)

# %%
province_confirmed_case = []
for i in unique_provinces:
    province_confirmed_case.append(data[data.Confirmed>0][data['Province/State']==i][data['Last Update']==latest_date].Confirmed.sum())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
print(set(zip(unique_provinces, province_confirmed_case)))
# Out:
# {('Ternopil Oblast', 0), ('Mayotte', 0), ('Kiev', 0), ('Wakayama', 0), ('Nuble', 0), ('Guizhou', 0), ('Manipur', 0), ('Aguascalientes', 0), ('Baja California Sur', 0), ('Navarra', 0), ('Andhra Pradesh', 0), ('Lviv Oblast', 0), ('Biobio', 0), ('Hyogo', 0), ('La Rioja', 0), ('Queretaro', 0), ('Fukushima', 0), ('Baja California', 0), ('Ingushetia Republic', 0), ('Cordoba', 0), ('Magadan Oblast', 0), ('Mato Grosso do Sul', 0), ('Nordrhein-Westfalen', 0), ('Assam', 0), ('Gibraltar', 0), ('Cherkasy Oblast', 0), ('Puglia', 0), ('West Bengal', 0), ('Bermuda', 0), ('Galicia', 0), ('Molise', 0), ('Kumamoto', 0), ('Nara', 0), ('Zabaykalsky Krai', 0), ('Melilla', 0), ('San Luis Potosi', 0), ('Baden-Wurttemberg', 0), ('Mexico', 0), ('Ivano-Frankivsk Oblast', 0), ('Nuevo Leon', 0), ('Tamil Nadu', 0), ('Toscana', 0), ('Rio Grande do Sul', 0), ('Cesar', 0), ('Guainia', 0), ('Marche', 0), ('Nova Scotia', 0), ('Astrakhan Oblast', 0), ('Choco', 0), ('Ceuta', 0), ('Tripura', 0), ('Tasmania', 0), ('Curacao', 0), ('Reunion', 0), ('Karnataka', 0), ('Western Australia', 0), ('Isle of Man', 0), ('Coahuila', 0), ('Bolivar', 0), ('Volgograd Oblast', 0), ('Santander', 0), ('Yamanashi', 0), ('Tabasco', 0), ('Okayama', 0), ('Chihuahua', 0), ('Leningrad Oblast', 0), ('Meghalaya', 0), ('Denmark', 0), ('Coquimbo', 0), ('Mykolaiv Oblast', 0), ('Caqueta', 0), ('Maule', 0), ('Netherlands', 0), ('Puducherry', 0), ('Piaui', 0), ('Kagoshima', 0), ('Bahia', 0), ('Campania', 0), ('France', 0), ('Punjab', 0), ('Faroe Islands', 0), ('Beijing', 0), ('Hamburg', 0), ('Friuli Venezia Giulia', 0), ('Cantabria', 0), ('Emilia-Romagna', 0), ('Fukui', 0), ('Tyumen Oblast', 0), ('Minas Gerais', 0), ('P.A. Bolzano', 0), ('Sonora', 0), ('Saarland', 0), ('Tatarstan Republic', 0), ('Extremadura', 0), ('Tokushima', 0), ('Taiwan', 0), ('Balochistan', 0), ('Kurgan Oblast', 0), ('Hainan', 0), ('Kentucky', 0), ('Cayman Islands', 0), ('Madrid', 0), ('Chernivtsi Oblast', 0), ('United Kingdom', 0), ('Shizuoka', 0), ('Khmelnytskyi Oblast', 0), ('Mato Grosso', 0), ('Hubei', 0), ('Thuringen', 0), ('Anhui', 0), ('Yamagata', 0), ('Michigan', 0), ('Basilicata', 0), ('Orel Oblast', 0), ('Ciudad de Mexico', 0), ('Umbria', 0), ('Arunachal Pradesh', 0), ('Tula Oblast', 0), ('Jammu and Kashmir', 0), ('Iwate', 0), ('Norte de Santander', 0), ('Sao Paulo', 0), ('Risaralda', 0), ('Rio Grande do Norte', 0), ('Delhi', 0), ('Puebla', 0), ('Nagaland', 0), ('Haryana', 0), ('Castilla y Leon', 0), ('Vladimir Oblast', 0), ('Casanare', 0), ('Pskov Oblast', 0), ('Shanghai', 0), ('Australian Capital Territory', 0), ('Nagasaki', 0), ('Ishikawa', 0), ('Tver Oblast', 0), ('Andaman and Nicobar Islands', 0), ('Nagano', 0), ('Veracruz', 0), ('Chongqing', 0), ('Pernambuco', 0), ('Durango', 0), ('Huila', 0), ('Piemonte', 0), ('Acre', 0), ('Komi Republic', 0), ('Saint Petersburg', 0), ('Lombardia', 0), ('Sumy Oblast', 0), ('Sinaloa', 0), ('Bayern', 0), ('New Brunswick', 0), ('Novgorod Oblast', 0), ('Maharashtra', 0), ('Ceara', 0), ('Sucre', 0), ('Islamabad', 0), ('Illinois', 0), ('Uttarakhand', 0), ('Sicilia', 0), ('Tolima', 0), ('Murcia', 0), ('Nenets Autonomous Okrug', 0), ('Amapa', 0), ('Murmansk Oblast', 0), ('Tlaxcala', 0), ('Heilongjiang', 0), ('Hiroshima', 0), ('Ivanovo Oblast', 0), ('Perm Krai', 0), ('Quebec', 0), ('Maranhao', 0), ('Chuvashia Republic', 0), ('Sachsen-Anhalt', 0), ('Voronezh Oblast', 0), ('Sint Maarten', 0), ('Unknown', 0), ('C. Valenciana', 0), ('Aruba', 0), ('Rheinland-Pfalz', 0), ('Para', 0), ('Arkhangelsk Oblast', 0), ('Newfoundland and Labrador', 0), ('Guerrero', 0), ('Narino', 0), ('Hessen', 0), ('Odessa Oblast', 0), ('Zhejiang', 0), ('Kursk Oblast', 0), ('OHiggins', 0), ('Caldas', 0), ('Jalisco', 0), ('Irkutsk Oblast', 0), ('Victoria', 0), ('Vologda Oblast', 0), ('Tocantins', 0), ('Khyber Pakhtunkhwa', 0), ('Fukuoka', 0), ('Goias', 0), ('Chhattisgarh', 0), ('British Columbia', 0), ('Khakassia Republic', 0), ('Montserrat', 0), ('Kerala', 0), ('Guanajuato', 0), ('Manitoba', 0), ('Port Quarantine' ...

# %%
nan_indices = []
for i in range(len(unique_provinces)):
  if type(unique_provinces[i])==float:
    nan_indices.append(i)

# %%
unique_provinces = list(unique_provinces)
province_confirmed_case = list(province_confirmed_case)

# %%
for i in nan_indices:
    unique_provinces.pop(i)
    province_confirmed_case.pop(i)

unique_provinces
# Out:
# ['Hubei',
#  'Shanghai',
#  'Beijing',
#  'Henan',
#  'Sichuan',
#  'Hainan',
#  'Chongqing',
#  'Heilongjiang',
#  'Hebei',
#  'Tianjin',
#  'Guizhou',
#  'Guangdong',
#  'Jilin',
#  'Hunan',
#  'Gansu',
#  'Anhui',
#  'Shandong',
#  'Guangxi',
#  'Jiangxi',
#  'Liaoning',
#  'Hong Kong',
#  'Xinjiang',
#  'Taiwan',
#  'Yunnan',
#  'Zhejiang',
#  'Diamond Princess cruise ship',
#  'Fujian',
#  'Shaanxi',
#  'Seattle, WA',
#  'King County, WA',
#  'Inner Mongolia',
#  'New South Wales',
#  'British Columbia',
#  'Washington',
#  'California',
#  'France',
#  'UK',
#  'United Kingdom',
#  'Denmark',
#  'Netherlands',
#  'New Jersey',
#  'Kentucky',
#  'Ontario',
#  'Illinois',
#  'Western Australia',
#  'French Polynesia',
#  'Curacao',
#  'Queensland',
#  'Victoria',
#  'Guadeloupe',
#  'Australian Capital Territory',
#  'St Martin',
#  'Martinique',
#  'Mayotte',
#  'Tasmania',
#  'Sint Maarten',
#  'Channel Islands',
#  'Cayman Islands',
#  'Bermuda',
#  'Isle of Man',
#  'South Australia',
#  'Aruba',
#  'British Virgin Islands',
#  'French Guiana',
#  'Turks and Caicos Islands',
#  'Montserrat',
#  'Abruzzo',
#  'Alberta',
#  'Andalusia',
#  'Aragon',
#  'Asturias',
#  'Baden-Wurttemberg',
#  'Baleares',
#  'Basilicata',
#  'Bayern',
#  'Berlin',
#  'Brandenburg',
#  'Bremen',
#  'C. Valenciana',
#  'Calabria',
#  'Campania',
#  'Canarias',
#  'Cantabria',
#  'Castilla - La Mancha',
#  'Castilla y Leon',
#  'Catalonia',
#  'Ceuta',
#  'Emilia-Romagna',
#  'Extremadura',
#  'Friuli Venezia Giulia',
#  'Galicia',
#  'Hamburg',
#  'Hessen',
#  'La Rioja',
#  'Lazio',
#  'Liguria',
#  'Lombardia',
#  'Madrid',
#  'Manitoba',
#  'Marche',
#  'Mecklenburg-Vorpommern',
#  'Melilla',
#  'Molise',
#  'Murcia',
#  'Navarra',
#  'Newfoundland and Labrador',
#  'Niedersachsen',
#  'Nordrhein-Westfalen',
#  'Nova Scotia',
#  'P.A. Bolzano',
#  'P.A. Trento',
#  'Pais Vasco',
#  'Piemonte',
#  'Puglia',
#  'Quebec',
#  'Rheinland-Pfalz',
#  'Saarland',
#  'Sachsen',
#  'Sachsen-Anhalt',
#  'Sardegna',
#  'Saskatchewan',
#  'Schleswig-Holstein',
#  'Sicilia',
#  'Thuringen',
#  'Toscana',
#  'Umbria',
#  'Unknown',
#  "Valle d'Aosta",
#  'Veneto',
#  'Aguascalientes',
#  'Baja California',
#  'Baja California Sur',
#  'Campeche',
#  'Chiapas',
#  'Chihuahua',
#  'Ciudad de Mexico',
#  'Coahuila',
#  'Colima',
#  'Durango',
#  'Guanajuato',
#  'Guerrero',
#  'Hidalgo',
#  'Jalisco',
#  'Mexico',
#  'Michoacan',
#  'Morelos',
#  'Nayarit',
#  'Nuevo Leon',
#  'Oaxaca',
#  'Puebla',
#  'Queretaro',
#  'Quintana Roo',
#  'Reunion',
#  'San Luis Potosi',
#  'Sinaloa',
#  'Sonora',
#  'Tabasco',
#  'Tamaulipas',
#  'Tlaxcala',
#  'Veracruz',
#  'Yucatan',
#  'Zacatecas',
#  'Aichi',
#  'Amazonas',
#  'Antioquia',
#  'Aomori',
#  'Atlantico',
#  'Bolivar',
#  'Boyaca',
#  'Caldas',
#  'Capital District',
#  'Caqueta',
#  'Cauca',
#  'Cesar',
#  'Chiba',
#  'Choco',
#  'Cordoba',
#  'Cundinamarca',
#  'Ehime',
#  'Fukui',
#  'Fukuoka',
#  'Gifu',
#  'Gunma',
#  'Hiroshima',
#  'Hokkaido',
#  'Huila',
#  'Hyogo',
#  'Ibaraki',
#  'Ishikawa',
#  'Kanagawa',
#  'Kochi',
#  'Kumamoto',
#  'Kyoto',
#  'La Guajira',
#  'Magdalena',
#  'Meta',
#  'Mie',
#  'Miyagi',
#  'Nagasaki',
#  'Nara',
#  'Narino',
#  'Norte de Santander',
#  'Oita',
#  'Okinawa',
#  'Osaka',
#  'Quindio',
#  'Risaralda',
#  'Saitama',
#  'Santander',
#  'Shiga',
#  'Shizuoka',
#  'Tokushima',
#  'Tokyo',
#  'Tolima',
#  'Toyama',
#  'Valle del Cauca',
#  'Wakayama',
#  'Yamanashi',
#  'Putumayo',
#  'Adygea Republic',
#  'Altai Krai',
#  'Amur Oblast',
#  'Arkhangelsk Oblast',
#  'Astrakhan Oblast',
#  'Bashkortostan Republic',
#  'Belgorod Oblast',
#  'Bryansk Oblast',
#  'Buryatia Republic',
#  'Chechen Republic',
#  'Chelyabinsk Oblast',
#  'Cherkasy Oblast',
#  'Chernihiv Oblast',
#  'Chernivtsi Oblast',
#  'Chukotka Autonomous Okrug',
#  'Chuvashia Republic',
#  'Crimea Republic*',
#  'Dagestan Republic',
#  'Dnipropetrovsk Oblast',
#  'Donetsk Oblast',
#  'Ingushetia Republic',
#  'Irkutsk Oblast',
#  'Ivano-Frankivsk Oblast',
#  'Ivanovo Oblast',
#  'Jewish Autonomous Okrug',
#  'Kabardino-Balkarian Republic',
#  'Kaliningrad Oblast',
#  'Kalmykia Republic',
#  'Kaluga Oblast',
#  'Kamchatka Krai',
#  'Karachay-Cherkess Republic',
#  'Karelia Republic',
#  'Kemerovo Oblast',
#  'Khabarovsk Krai',
#  'Khakassia Republic',
#  'Khanty-Mansi Autonomous Okrug',
#  'Kharkiv Oblast',
#  'Kherson Oblast',
#  'Khmelnytskyi Oblast',
#  'Kiev',
#  'Kiev Oblast',
#  'Kirov Oblast',
#  'Kirovohrad Oblast',
#  'Komi Republic',
#  'Kostroma Oblast',
#  'Krasnodar Krai',
#  'Krasnoyarsk Krai',
#  'Kursk Oblast',
#  'Leningrad Oblast',
#  'Lipetsk Oblast',
#  'Lviv Oblast',
#  'Magadan Oblast',
#  'Mari El Republic',
#  'Mordovia Republic',
#  'Moscow',
#  'Moscow Oblast',
#  'Murmansk Oblast',
#  'Mykolaiv Oblast',
#  'Nizhny Novgorod Oblast',
#  'North Ossetia - Alania Republic',
#  'Novgorod Oblast',
#  'Novosibirsk Oblast',
#  'Odessa Oblast',
#  'Omsk Oblast',
#  'Orel Oblast',
#  'Orenburg Oblast',
#  'Penza Oblast',
#  'Perm Krai',
#  'Poltava Oblast',
#  'Primorsky Krai',
#  'Pskov Oblast',
#  'Rivne Oblast',
#  'Rostov Oblast',
#  'Ryazan Oblast',
#  'Saint Petersburg',
#  'Sakha (Yakutiya) Republic',
#  'Samara Oblast',
#  'Saratov Oblast',
#  'Sevastopol*',
#  'Smolensk Oblast',
#  'Stavropol Krai',
#  'Sumy Oblast',
#  'Sverdlovsk Oblast',
#  'Tambov Oblast',
#  'Tatarstan Republic',
#  'Ternopil Oblast',
#  'Tomsk Oblast',
#  'Tula Oblast',
#  'Tver Oblast',
#  'Tyumen Oblast',
#  'Tyva Republic',
#  'Udmurt Republic',
#  'Ulyanovsk Oblast',
#  'Vinnytsia Oblast',
#  'Vladimir Oblast',
#  'Volgograd Oblast',
#  'Vologda Oblast',
#  'Volyn Oblast',
#  'Voronezh Oblast',
#  'Yamalo-Nenets Autonomous Okrug',
#  'Yaroslavl Oblast',
#  'Zabaykalsky Krai',
#  'Zakarpattia Oblast',
#  'Zaporizhia Oblast',
#  'Zhytomyr Oblast',
#  'New Brunswick',
#  'Casanare',
#  'Sucre',
#  'Acre',
#  'Alagoas',
#  'Amapa',
#  'Bahia',
#  'Ceara',
#  'Distrito Federal',
#  'Espirito Santo',
#  'Maranhao',
#  'Mato Grosso',
#  'Mato Grosso do Sul',
#  'Minas Gerais',
#  'Para',
#  'Paraiba',
#  'Parana',
#  'Pernambuco',
#  'Piaui',
#  'Rio Grande do Norte',
#  'Rio Grande do Sul',
#  'Rio de Janeiro',
#  'Rondonia',
#  'Roraima',
#  'Santa Catarina',
#  'Sao Paulo',
#  'Sergipe',
#  'Tocantins',
#  'Michigan',
#  'Andhra Pradesh',
#  'Assam',
#  'Azad Jammu and Kashmir',
#  'Balochistan',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Delhi',
#  'Gilgit-Baltistan',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Islamabad',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Khyber Pakhtunkhwa',
#  'Ladakh',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Meghalaya',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sindh',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal',
#  'Puducherry',
#  'Guainia',
#  'San Andres y Providencia',
#  'Goa',
#  'Port Quarantine',
#  'Arunachal Pradesh',
#  'Kurgan Oblast',
#  'Antofagasta',
#  'Araucania',
#  'Arica y Parinacota',
#  'Atacama',
#  'Biobio',
#  'Coquimbo',
#  'Los Lagos',
#  'Los Rios',
#  'Magallanes',
#  'Maule',
#  'Metropolitana',
#  'Nuble',
#  'OHiggins',
#  'Tarapaca',
#  'Valparaiso',
#  'Altai Republic',
#  'Vaupes',
#  'Yamagata',
#  'Goias',
#  'Dadra and Nagar Haveli and Daman and Diu',
#  'Luhansk Oblast',
#  'Aysen',
#  'Arauca',
#  'Nagaland',
#  'Andaman and Nicobar Islands',
#  'Sikkim',
#  'Kagoshima',
#  'Manipur',
#  'Tochigi',
#  'Miyazaki',
#  'Kagawa',
#  'Vichada',
#  'Guaviare',
#  'Okayama',
#  'Nagano',
#  'Yamaguchi',
#  'Bonaire, Sint Eustatius and Saba',
#  'Fukushima',
#  'Nenets Autonomous Okrug',
#  'Sakhalin Oblast',
#  'Saga',
#  'Mizoram',
#  'Yukon',
#  'Gibraltar',
#  'Iwate',
#  'Akita',
#  'Saint Barthelemy',
#  'Niigata',
#  'Nunavut',
#  'Faroe Islands',
#  'Tottori']

# %%
plt.barh(unique_countries, country_confirmed_case)
plt.show()

# %%
plt.figure(figsize=(50,40))
plt.barh(unique_provinces, province_confirmed_case)
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.pie(country_confirmed_case)
plt.legend(unique_countries, loc='best')
plt.show()

# %%
plt.figure(figsize=(20,20))
plt.pie(province_confirmed_case)
plt.legend(unique_provinces, loc='best')
plt.show()

# %% [markdown]
# **Selesai**
